# %%
#匯入牌組資料
import pandas as pd
card_data=pd.read_excel("塔羅牌資料.xlsx")
card_data
# Out:
#                           牌名  \
# 0                愚者 The Fool
# 1           魔術師 The Magician
# 2     女祭司 The High Priestess
# 3             皇后 The Empress
# 4             皇帝 The Emperor
# ..                       ...
# 73      錢幣十 Ten of Pentacles
# 74    錢幣侍者 Page of Pentacles
# 75  錢幣騎士 Knight of Pentacles
# 76   錢幣皇后 Queen of Pentacles
# 77    錢幣國王 King of Pentacles
#
#                                                  正位牌義  \
# 0   愚者的正位牌義：/n正位的愚者牌代表已經被推算過的風險。重新起頭、跟隨心的渴望，永遠不嫌太遲...
# 1   魔術師的正位牌義：/n現在正是行動時刻——請將你的想法和願望表達出來，與他人溝通，這是一張屬...
# 2   女祭司的正位牌義：/n隱密的知識、直覺力、通靈經驗，以及預示夢境，都是女祭司的天賦。這是一段...
# 3   皇后的正位牌義：/n皇后的禮物是豐盛及物質上的舒適、滿足與安全感，以及情感上的支持。對兒童和...
# 4   皇帝的正位牌義：/n在占卜解牌中，皇帝可以代表一個擁有威權力以及象徵統治與野心的傳統陽性面。...
# ..                                                ...
# 73  錢幣十的正位牌義：/n正位的錢幣十，代表能夠帶來財富與幸福的遺產、慷慨之心，以及愛情——因此...
# 74  錢幣侍者的正位牌義：/n代表影響力：錢幣侍者代表進步與冒險，抽到此塔羅代表你會開門見喜、一切...
# 75  錢幣騎士的正位牌義：/n代表影響力：這預示經濟收入增加、投資有成，這張塔羅牌出現意味著財產的...
# 76  錢幣皇后的正位牌義：/n代表某個人：錢幣皇后通常非常有錢、慷慨、樂意助人。她擁有強大的母性本...
# 77  錢幣國王的正位牌義：/n代表某個人：一位有遠見、計畫周全的人，國王會努力工作追求成果，而且通...
#
#                                                  逆位牌義  \
# 0   愚者的逆位牌義：/n你所提議的事情，是否太過荒誕不可行？你眼前的機會是否風險太過巨大？逆位的...
# 1   魔術師的逆位牌義：/n好的魔術師如果倒轉過來，就變成了騙子。所以，如果出現了逆位的魔術師，表...
# 2   女祭司的逆位牌義：/n女祭司逆位，可能代表了這位心靈導師不適合你，或是你目前選擇的那條道路是...
# 3   皇后的逆位牌義：/n皇后牌的逆位，代表經濟上出了問題，或是家人之間有爭執。這很可能導致家庭中...
# 4   皇帝的逆位牌義：/n處於逆位的皇帝，代表對於權力的渴望而且需求過度，也代表傳統男性力量的負面...
# ..                                                ...
# 73  錢幣十的逆位牌義：/n逆位的錢幣十，代表家庭當中出現溝通問題，年長的一輩想要對晚輩嚴加控制；...
# 74  錢幣侍者的逆位牌義：/n逆位的錢幣侍者，象徵在財務或房產方面有不好的消息。逆位的錢幣侍者不像...
# 75  錢幣騎士的逆位牌義：/n逆位錢幣騎士象徵一位忠誠而且可以倚靠的人。他天生就是一個保護者，對他...
# 76  錢幣皇后的逆位牌義：/n逆位的錢幣皇后，表示財務出現困難。你賴以為生的金錢收入可能突然中斷，...
# 77  錢幣國王的逆位牌義：/n逆位的錢幣國王，代表貪婪與不值得信靠，因此如果占卜時出現這張塔羅牌，...
#
#                                                    網址
# 0   https://tarotapp.s3.amazonaws.com/p/img_pool/F...
# 1   https://tarotapp.s3.amazonaws.com/p/img_pool/j...
# 2   https://tarotapp.s3.amazonaws.com/p/img_pool/D...
# 3   https://tarotapp.s3.amazonaws.com/p/img_pool/v...
# 4   https://tarotapp.s3.amazonaws.com/p/img_pool/R...
# ..                                                ...
# 73  https://tarotapp.s3.amazonaws.com/p/img_pool/a...
# 74  https://tarotapp.s3.amazonaws.com/p/img_pool/Q...
# 75  https://tarotapp.s3.amazonaws.com/p/img_pool/Y...
# 76  https://tarotapp.s3.amazonaws.com/p/img_pool/=...
# 77  https://tarotapp.s3.amazonaws.com/p/img_pool/B...
#
# [78 rows x 4 columns]

# %%
#初始抽牌template
start={
    "type": "buttons",
    "thumbnailImageUrl": "https://i.imgur.com/NQPjz4s.jpg",
    "imageAspectRatio": "square",
    "imageSize": "contain",
    "imageBackgroundColor": "#FFFFFF",
    "title": "小戴塔羅、鐵口直斷",
    "text": "點選下方開始抽牌",
    "actions": [
      {
        "type": "postback",
        "label": "抽牌",
        "data": "抽牌"
      }
    ]
  }

# %%
import random as rd
pn=["正","逆"]#positive or negative
#抽牌結果[[牌號1,正逆],[牌號2,正逆],[牌號3,正逆]] 1正2逆
def draw_cards():
    global card_numbers
    global card_list
    global card
    card_list=[]
    card_numbers = rd.sample(range(0, 77), 3)#抽三張不重複
    for card in card_numbers:
        card_list.append([card,rd.randint(1,2)])
    print("使用者抽牌:",card_list)
    #抽牌結果
    card={
  "type": "carousel",
  "contents":[
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "baseline",
        "contents": [
          {
            "type": "text",
            "text": "過去",
            "color": "#FF9D00FF",
            "align": "center"
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": card_data.iat[card_list[0][0],3],
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": card_data.iat[card_list[0][0],0]+pn[card_list[0][1]-1],
            "align": "center"
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "觀看牌義",
              "data": str(card_list[0][0])
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "baseline",
        "contents": [
          {
            "type": "text",
            "text": "現在",
            "color": "#FF9D00FF",
            "align": "center"
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": card_data.iat[card_list[1][0],3],
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": card_data.iat[card_list[1][0],0]+pn[card_list[1][1]-1],
            "align": "center"
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "觀看牌義",
              "data": str(card_list[1][0])
            }
          }
        ]
      }
    },
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "baseline",
        "contents": [
          {
            "type": "text",
            "text": "未來",
            "color": "#FF9D00FF",
            "align": "center",
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": card_data.iat[card_list[2][0],3],
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": card_data.iat[card_list[2][0],0]+pn[card_list[2][1]-1],
            "align": "center"          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "觀看牌義",
              "data": str(card_list[2][0])
            }
          }
        ]
      }
    }
  ]
}

# %%
from flask import Flask, request
from linebot import LineBotApi
from linebot.models import FlexSendMessage, TextSendMessage,TemplateSendMessage
app = Flask(__name__)

# LINE 聊天機器人的基本資料
line_bot_api = LineBotApi('H1kHh9Yyqd5g1HWbUc6ApVg0mEtbgNLafTsN6IFTUMNVh17+wOO80U6eg+5vwXYtujb9rRtdJjQcJ0ZdOJvQrquiL7OCp5lEcKmO3ID8q0fyawsJQ2mXJ0W5qvFENaWmWBcbXbcp3KABqquuIhYzNQdB04t89/1O/w1cDnyilFU=')
@app.route("/", methods=['POST'])
def fortune():
    data = request.get_json()
    print(data)
    if len(data['events'])==0:#驗證模式events是空的
        print("webhook驗證OK")
        return 'Verify OK',200
    elif data['events'][0]['type']=="message" and len(data['events'])==1:#任何文字訊息皆發送啟動template
        if data['events'][0]['message']["text"]!="開始抽牌":    
            line_bot_api.reply_message(data['events'][0]['replyToken'],
            TemplateSendMessage(alt_text="123", template=start))
    if data['events'][0]['type']=="postback":
        if data['events'][0]["postback"]["data"]=="抽牌":#使用者點選抽牌
            draw_cards()
            line_bot_api.reply_message(data['events'][0]['replyToken'],
            FlexSendMessage(alt_text="456",contents=card))
        else:#使用者點選觀看牌義
            card_num=int(data['events'][0]["postback"]["data"])
            line_bot_api.reply_message(data['events'][0]['replyToken'],
            TextSendMessage(text=card_data.iat[card_num,card_list[card_numbers.index(card_num)][1]]))
    return 'OK',200
if __name__ == "__main__":
    app.run(port=3000)#需與NGROK的通道阜相同
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# C:\Users\hp\AppData\Local\Temp\ipykernel_18952\4287104432.py:7: LineBotSdkDeprecatedIn30: Call to deprecated class LineBotApi. (Use v3 class; linebot.v3.<feature>. See https://github.com/line/line-bot-sdk-python/blob/master/README.rst for more details.) -- Deprecated since version 3.0.0.
#   line_bot_api = LineBotApi('H1kHh9Yyqd5g1HWbUc6ApVg0mEtbgNLafTsN6IFTUMNVh17+wOO80U6eg+5vwXYtujb9rRtdJjQcJ0ZdOJvQrquiL7OCp5lEcKmO3ID8q0fyawsJQ2mXJ0W5qvFENaWmWBcbXbcp3KABqquuIhYzNQdB04t89/1O/w1cDnyilFU=')
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:3000
# Press CTRL+C to quit
# C:\Users\hp\AppData\Local\Temp\ipykernel_18952\4287104432.py:17: LineBotSdkDeprecatedIn30: Call to deprecated method reply_message. (Use 'from linebot.v3.messaging import MessagingApi' and 'MessagingApi(...).reply_message(...)' instead. See https://github.com/line/line-bot-sdk-python/blob/master/README.rst for more details.) -- Deprecated since version 3.0.0.
#   line_bot_api.reply_message(data['events'][0]['replyToken'],
# 127.0.0.1 - - [08/Apr/2025 21:21:46] "POST / HTTP/1.1" 200 -
# {'destination': 'Uf69776963507ff8f85b6c9f22ea919e4', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '555807694381122136', 'quoteToken': 'DPNVtEkR0g-zD1wa083sT05C_TNoWmzGscRsy_gmTKUOTsbMa22AV-jH1GU_GhnNgHi_0vwxFTV_yplkUCbL49NLHSsrP6HwSyCds11v2S68KDGDgLStFQ1MxVyWNy-AU1YoqqMHAOSWYzDCGabDGw', 'text': '123'}, 'webhookEventId': '01JRAS0RX3GADTA28YB55VDQX3', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1744118505907, 'source': {'type': 'user', 'userId': 'Uc73d64c0bd21b9cebea8a7ecda34201f'}, 'replyToken': '8022ab0bedc94ec19683a161eea4edf9', 'mode': 'active'}]}
# {'destination': 'Uf69776963507ff8f85b6c9f22ea919e4', 'events': [{'type': 'postback', 'postback': {'data': '抽牌'}, 'webhookEventId': '01JRAS16DQW9NMXKYKGGHV26JT', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1744118519744, 'source': {'type': 'user', 'userId': 'Uc73d64c0bd21b9cebea8a7ecda34201f'}, 'replyToken': '0ad90673870f47f0b6a0e1745d454fd9', 'mode': 'active'}]}
# 使用者抽牌: [[61, 1], [7, 2], [72, 1]]
# C:\Users\hp\AppData\Local\Temp\ipykernel_18952\4287104432.py:22: LineBotSdkDeprecatedIn30: Call to deprecated method reply_message. (Use 'from linebot.v3.messaging import MessagingApi' and 'MessagingApi(...).reply_message(...)' instead. See https://github.com/line/line-bot-sdk-python/blob/master/README.rst for more details.) -- Deprecated since version 3.0.0.
#   line_bot_api.reply_message(data['events'][0]['replyToken'],
# 127.0.0.1 - - [08/Apr/2025 21:22:00] "POST / HTTP/1.1" 200 -
# C:\Users\hp\AppData\Local\Temp\ipykernel_18952\4287104432.py:26: LineBotSdkDeprecatedIn30: Call to deprecated method reply_message. (Use 'from linebot.v3.messaging import MessagingApi' and 'MessagingApi(...).reply_message(...)' instead. See https://github.com/line/line-bot-sdk-python/blob/master/README.rst for more details.) -- Deprecated since version 3.0.0.
#   line_bot_api.reply_message(data['events'][0]['replyToken'],
# 127.0.0.1 - - [08/Apr/2025 21:23:20] "POST / HTTP/1.1" 200 -
# {'destination': 'Uf69776963507ff8f85b6c9f22ea919e4', 'events': [{'type': 'postback', 'postback': {'data': '7'}, 'webhookEventId': '01JRAS3MSH76AQC0S1G1TT3WSM', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1744118599994, 'source': {'type': 'user', 'userId': 'Uc73d64c0bd21b9cebea8a7ecda34201f'}, 'replyToken': '309b5bf551c0466f9e5206036e1b12d3', 'mode': 'active'}]}
