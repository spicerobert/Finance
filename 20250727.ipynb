# %%
pip install -q -U google-genai

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
token = "AIzaSyAIxvmlKIlilpkIGEefcWrnB_ZOlB5kzkc"
client = genai.Client(api_key="token")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)

# %%
mes2 = {
    "type": "template",
    "altText": "這是按鈕範本訊息",
    "template": {
        "type": "buttons",
        "thumbnailImageUrl": "https://example.com/image.jpg",
        "title": "按鈕標題",
        "text": "按鈕內容",
        "actions": [
            {
                "type": "postback",
                "label": "按鈕1",
                "data": "action=buy&itemid=123"
            },
            {
                "type": "uri",
                "label": "按鈕2",
                "uri": "https://example.com"
            }
        ]
    }
}



mes1 =flex_message_payload = {
    "type": "flex",
    "altText": "這是互動原型型訊息",
    "contents":   "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "direction": "ltr",
      "header": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "NASDAQ index",
            "align": "center",
            "contents": []
          }
        ]
      },
      "hero": {
        "type": "image",
        "url": "https://tse3.mm.bing.net/th/id/OIP.iZ84B5JnqNUoBOYXXAn2cAHaE8?rs=1&pid=ImgDetMain&o=7&rm=3.jpeg",
        "size": "full",
        "aspectRatio": "1.51:1",
        "aspectMode": "fit"
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "text",
            "text": "This is up-to-date NASDAQ information",
            "align": "center",
            "contents": []
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "horizontal",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "Button",
              "uri": "https://linecorp.com"
            }
          }
        ]
      }
    }
  ]
}

# %%
"""
HTTP呼叫模式
參考Message API資料，以request呼叫
https://developers.line.biz/en/reference/messaging-api/#send-reply-message
"""


mes1 = {
    "type": "flex",
    "altText": "這是互動原型型訊息",
    "contents":{
  "type": "bubble",
  "direction": "ltr",
  "header": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "NASDAQ index",
        "align": "center",
        "contents": []
      }
    ]
  },
  "hero": {
    "type": "image",
    "url": "https://tse3.mm.bing.net/th/id/OIP.iZ84B5JnqNUoBOYXXAn2cAHaE8?rs=1&pid=ImgDetMain&o=7&rm=3.jpeg",
    "size": "full",
    "aspectRatio": "1.51:1",
    "aspectMode": "fit"
  },
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "This is up-to-date NASDAQ information",
        "align": "center",
        "contents": []
      }
    ]
  },
  "footer": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": "Button",
          "text": "sdadsasd"
        }
      }
    ]
  }
}
}


import requests
import pandas as pd
import math
import time
import requests
from flask import Flask, request
from datetime import datetime
import json

# Get current time
def Display():
    now = datetime.now()

# 初始化 Flask 應用程式
app = Flask(__name__)

# 設定 LINE BOT Token
BOT_TOKEN = "O2B1kJid4+1jyJ0s6ZUKd5Icr1PupxuTkVFPXxPzurcnrk7tE+B/+zfflrNzFxZMoj1+Qc8o53f/UZhURmLcdLswTL4A6Q9yxRnYGaiSDbLRp+4UbjDoOJtLAWav3OPtxtQbo+XbfBXmd7wcEMVMwwdB04t89/1O/w1cDnyilFU="

# 傳送文字訊息函數
def send_text_message(reply_token, text):

    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer " + BOT_TOKEN
    }

    payload = {
        "replyToken": reply_token,
        "messages": [text]
    }

    # 發送 POST 請求至 LINE Messaging API
    response = requests.post(
        "https://api.line.me/v2/bot/message/reply",
        headers=headers,
        json=payload
    )
    return response

# LINE Webhook 入口
@app.route("/", methods=['POST'])
def linebot():
    global 年份
    # 取得使用者傳來的資料
    data = request.get_json()
    print(data)
    print("!!!!!destination : ", data['destination'])
    print("!!!!!events : ", data['events'])
    print("!!!!!events[0] : ", data['events'][0])
    print("!!!!!events[0]['type'] : ", data['events'][0]['type'])
    print("!!!!!events[0]['message'] : ", data['events'][0]['message'])
    print("!!!!!events[0]['message']['text'] : ", data['events'][0]['message']['text'])
    print("!!!!!events[0]['message']['text'][1:2] : ", data['events'][0]['message']['text'][0:2])
    print("!!!!!events[0]['message']['text'][2:6] : ", data['events'][0]['message']['text'][2:6])
    print("!!!!!events[0]['webhookEventId'] : ", data['events'][0]['webhookEventId'])
    print("!!!!!events[0]['deliveryContext'] : ", data['events'][0]['deliveryContext'])
    print("!!!!!events[0]['source'] : ", data['events'][0]['source'])
    print("!!!!!events[0]['replyToken'] : ", data['events'][0]['replyToken'])
    print("!!!!!events[0]['mode'] : ", data['events'][0]['mode'])
    #print("!!!!!events[1] : ", data['events'][1])
    #print("!!!!!events[2] : ", data['events'][2])
    # 提取 replyToken
    reply_token = data['events'][0]['replyToken']
    now = datetime.now()

    # Convert datetime to string (ISO format is common)
    date_string = now.isoformat()

    # Create a dictionary to include in JSON

    # Convert to JSON string
    json_output = json.dumps(date_string)
    mes1["contents"]["footer"]["contents"][0]["action"]["text"] = json_output
    response = send_text_message(reply_token, mes1)
    print("mes1:", mes1["contents"]["footer"]["contents"][0]["action"]["text"])


    if response.status_code == 200:
        return "OK", 200
    else:
        print("發送訊息失敗:", response.status_code, response.text)
        return "Error", 400

# 啟動 Flask 伺服器
if __name__ == "__main__":
    app.run(port=3000)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:3000/ (Press CTRL+C to quit)
# {'destination': 'U8aaf62d0c1f51ecee43fb500b88ab56b', 'events': [{'type': 'message', 'message': {'type': 'text', 'id': '571716977349886471', 'quoteToken': 'fq9zFb2uSwV5QCqviT-_R8o89oXGTxPviR0HX12moE-yodejSRm4L26nxy9lQiSgqa239HGyUQ1WJhADzQwB1NVNUSdND4OfT3Ez0AWbf8uv2vccESSchphNOFP0rfm77K1wS_L-d-ufjwG7lKe6jg', 'text': 'dss'}, 'webhookEventId': '01K15CCXZE0W9G9XB06Y6DK0RJ', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1753
 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1753601181449, 'source': {'type': 'user', 'userId': 'Uba02226f1b3e5d840dd5305f46e74074'}, 'replyToken': 'a4014c83035145f7b5ec461f4811a58e', 'mode': 'active'}]}
# !!!!!destination :  U8aaf62d0c1f51ecee43fb500b88ab56b
# !!!!!events :  [{'type': 'message', 'message': {'type': 'text', 'id': '571716984010440790', 'quoteToken': 'C49sMsKRU6tkq9dObyGwvTl9RxWYjf1F--fowvVpLdbRpNffIK95DCJRFy7l7i_7IkfOgZHjlbV_JwjRlwM6fTN4olDMfwmMBWoqmKDxc5YGpDlS6h-nlgWkm7slGiuPZs54OoMLCJdCguNI7TxvHA', 'text': '"2025-07-27T15:26:20.034535"'}, 'webhookEventId': '01K15CD288HHSKZ2VVAFCK1971', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1753601181449, 'source': {'type': 'user', 'userId': 'Uba02226f1b3e5d840dd5305f46e74074'}, 'replyToken': 'a4014c83035145f7b5ec461f4811a58e', 'mode': 'active'}]
# !!!!!events[0] :  {'type': 'message', 'message': {'type': 'text', 'id': '571716984010440790', 'quoteToken': 'C49sMsKRU6tkq9dObyGwvTl9RxWYjf1F--fowvVpLdbRpNffIK95DCJRFy7l7i_7IkfOgZHjlbV_JwjRlwM6fTN4olDMfwmMBWoqmKDxc5YGpDlS6h-nlgWkm7slGiuPZs54OoMLCJdCguNI7TxvHA', 'text': '"2025-07-27T15:26:20.034535"'}, 'webhookEventId': '01K15CD288HHSKZ2VVAFCK1971', 'deliveryContext': {'isRedelivery': False}, 'timestamp': 1753601181449, 'source': {'type': 'user', 'userId': 'Uba02226f1b3e5d840dd5305f46e74074'}, 'replyToken': 'a4014c83035145f7b5ec461f4811a58e', 'mode': 'active'}
# !!!!!events[0]['type'] :  message
# !!!!!events[0]['message'] :  {'type': 'text', 'id': '571716984010440790', 'quoteToken': 'C49sMsKRU6tkq9dObyGwvTl9RxWYjf1F--fowvVpLdbRpNffIK95DCJRFy7l7i_7IkfOgZHjlbV_JwjRlwM6fTN4olDMfwmMBWoqmKDxc5YGpDlS6h-nlgWkm7slGiuPZs54OoMLCJdCguNI7TxvHA', 'text': '"2025-07-27T15:26:20.034535"'}
# !!!!!events[0]['message']['text'] :  "2025-07-27T15:26:20.034535"
# !!!!!events[0]['message']['text'][1:2] :  "2
# !!!!!events[0]['message']['text'][2:6] :  025-
# !!!!!events[0]['webhookEventId'] :  01K15CD288HHSKZ2VVAFCK1971
# !!!!!events[0]['deliveryContext'] :  {'isRedelivery': False}
# !!!!!events[0]['source'] :  {'type': 'user', 'userId': 'Uba02226f1b3e5d840dd5305f46e74074'}
# !!!!!events[0]['replyToken'] :  a4014c83035145f7b5ec461f4811a58e
# !!!!!events[0]['mode'] :  active
# 127.0.0.1 - - [27/Jul/2025 15:26:22] "POST / HTTP/1.1" 200 -
# mes1: "2025-07-27T15:26:22.026696"
