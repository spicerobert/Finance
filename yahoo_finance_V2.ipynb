# %%
pip install yfinance matplotlib

# %%
year=input("輸入西元年")
month=input("輸入月份")
if len(month)!=2:
    month="0"+month
day=input("輸入日，請補0")
start_date=year+"-"+month+"-"+day
start_date

# %%
import yfinance as yf

# 設定股票代號和數據的時間範圍
stock_symbol = '0050.tw'
start_date = '2020-01-01'
end_date = '2024-12-31'

# 使用yfinance來獲取股票數據
data = yf.download(stock_symbol, start=start_date, end=end_date)

# 顯示數據的前幾行
print(data.head())

# %%
data.to_csv("0050_2332.csv")

# %%
print(data.columns)

# %%
import yfinance as yf

data = yf.download(
    tickers=["0050.tw", "2332.tw"],
    start="2023-01-01",
    end="2023-12-31",
    interval="1d",
)
# 顯示數據的前幾行
print(data.head())

# %%
import matplotlib.pyplot as plt
# 修改字體顯示
plt.rcParams['font.family'] = 'Microsoft JhengHei'  

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)  # 畫折線圖
plt.title("簡單折線圖")
plt.xlabel("X軸")
plt.ylabel("Y軸")
plt.show()

# %%
# 使用matplotlib來繪製收盤價走勢圖
plt.figure(figsize=(10, 2))
plt.plot(data['Close'], label='Close Price')
plt.title(f'{stock_symbol} Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
data["00878.TW"]
# Out:
# Date
# 2024-01-02    18.878443
# 2024-01-03    18.606998
# 2024-01-04    18.571976
# 2024-01-05    18.563217
# 2024-01-08    18.624512
#                 ...
# 2024-12-24    21.341682
# 2024-12-25    21.399078
# 2024-12-26    21.399078
# 2024-12-27    21.427774
# 2024-12-30    21.332115
# Name: 00878.TW, Length: 241, dtype: float64

# %%
import yfinance as yf
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Microsoft JhengHei'  
# 設定股票代號列表
stock_symbols = ['00915.TW', '00878.TW','00940.TW','00939.TW']
start_date = '2024-01-01'
end_date = '2024-12-31'

# 使用yfinance來一次獲取所有指定股票的數據
data = yf.download(stock_symbols, start=start_date, end=end_date)['Close']

# 顯示數據的前幾行
print(data.head())

# 使用matplotlib來繪製所有股票的收盤價走勢圖
plt.figure(figsize=(12, 6))
for symbol in stock_symbols:
    plt.plot(data[symbol], label=f'{symbol} Close Price')

plt.title('ETF比較',fontsize=18)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Price (NTD)',fontsize=18)
plt.legend(fontsize=18)
plt.tight_layout()
plt.savefig("ETF.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\1727870176.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbols, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  4 of 4 completed
# Ticker       00878.TW   00915.TW  00939.TW  00940.TW
# Date
# 2024-01-02  18.878443  19.460020       NaN       NaN
# 2024-01-03  18.606998  19.234949       NaN       NaN
# 2024-01-04  18.571976  19.252264       NaN       NaN
# 2024-01-05  18.563217  19.217636       NaN       NaN
# 2024-01-08  18.624512  19.139729       NaN       NaN

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 設定股票代號和數據的時間範圍
stock_symbol = '2330.TW'
start_date = '2022-06-01'
end_date = '2025-06-01'

# 使用yfinance來獲取股票數據
data = yf.download(stock_symbol, start=start_date, end=end_date)

# 計算技術指標：移動平均線（MA）
data['MA5'] = data['Close'].rolling(window=5).mean()
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA60'] = data['Close'].rolling(window=60).mean()
data['MA120'] = data['Close'].rolling(window=120).mean()

# 顯示數據的前幾行
print(data[['Close', 'MA5', 'MA20', 'MA60', 'MA120']].tail())

# 使用matplotlib來繪製股票價格與技術指標的走勢圖
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.plot(data['MA5'], label='5-Day MA')
plt.plot(data['MA20'], label='20-Day MA')
plt.plot(data['MA60'], label='60-Day MA')
plt.plot(data['MA120'], label='120-Day MA')
plt.title(f'{stock_symbol} Stock Price and Moving Averages')
plt.legend()
plt.tight_layout()
plt.savefig("2330TW.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\3281981141.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price            Close         MA5        MA20        MA60        MA120
# Ticker         2330.TW
# Date
# 2025-05-23  979.842224  979.443933  947.579141  936.588958  1002.452682
# 2025-05-26  971.876038  977.850696  951.960550  935.359084  1002.209428
# 2025-05-27  960.922485  975.261670  955.346182  933.864054  1001.627106
# 2025-05-28  962.914062  970.681104  958.582449  932.732603  1001.143976
# 2025-05-29  962.914062  967.693774  961.519983  931.931535  1000.826039

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 設定股票代號和數據的時間範圍
stock_symbol = '2330.TW'
start_date = '2022-06-01'
end_date = '2025-06-01'

# 使用yfinance來獲取股票數據
data = yf.download(stock_symbol, start=start_date, end=end_date)

# 計算技術指標：移動平均線（MA）
data['MA5'] = data['Close'].rolling(window=5).mean()
data['MA20'] = data['Close'].rolling(window=20).mean()
data['MA60'] = data['Close'].rolling(window=60).mean()
data['MA120'] = data['Close'].rolling(window=120).mean()

# 顯示數據的前幾行
print(data[['Close', 'MA20', 'MA120']].tail())

# 使用matplotlib來繪製股票價格與技術指標的走勢圖
plt.figure(figsize=(14, 7))
plt.plot(data['Close'], label='Close Price')
plt.plot(data['MA20'], label='20-Day MA')
plt.plot(data['MA120'], label='120-Day MA')
plt.title(f'{stock_symbol} Stock Price and Moving Averages')
plt.legend()
plt.tight_layout()
plt.savefig("2330TW.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\3222499358.py:10: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        MA20        MA120
# Ticker         2330.TW
# Date
# 2025-05-23  979.842224  947.579141  1002.452682
# 2025-05-26  971.876038  951.960550  1002.209428
# 2025-05-27  960.922485  955.346182  1001.627106
# 2025-05-28  962.914062  958.582449  1001.143976
# 2025-05-29  962.914062  961.519983  1000.826039

# %%
import time
while 1:
    print(123)
    time.sleep(2)

# %%
for y in range(2005,2025):
    print(str(y)+'-01-01')

# %%
data["0050.TW"][-1]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\234633855.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data["0050.TW"][-1]
# 55.3636589050293

# %%
import random
import yfinance as yf
# 設定股票代號和數據的時間範圍
stock_symbol = '0050.TW'
start_date = '2014-01-01'
end_date = '2014-12-31'

# 使用yfinance來獲取股票數據
data = yf.download(stock_symbol, start=start_date, end=end_date)
data["Close"]["0050.TW"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\4241875076.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Date
# 2014-01-02    47.334370
# 2014-01-03    46.768467
# 2014-01-06    46.647205
# 2014-01-07    46.647205
# 2014-01-08    46.728039
#                 ...
# 2014-12-24    54.908161
# 2014-12-25    54.908161
# 2014-12-26    55.032375
# 2014-12-29    55.653511
# 2014-12-30    55.363659
# Name: 0050.TW, Length: 247, dtype: float64

# %%
import random
import yfinance as yf
# 設定股票代號和數據的時間範圍
stock_symbol = '0050.TW'
start_date = '2014-01-01'
end_date = '2014-12-31'

# 使用yfinance來獲取股票數據
data = yf.download(stock_symbol, start=start_date, end=end_date)
stock1=0
stock2=0
for m in range(1,12+1):
    if m < 10 :
        stock1+=1000/data["Close"]["0050.TW"].loc["2014-"+f"0{m}"][0]
    else:
        stock1+=1000/data["Close"]["0050.TW"].loc["2014-"+f"{m}"][0]
print(stock1)
print(stock1*data["Close"]["0050.TW"][-1])
print((data["Close"]["0050.TW"][-1]/data["Close"]["0050.TW"][0])*12000)
for m in range(1,12+1):
    if m < 10 :
        n=random.randint(0,len(data["Close"]["0050.TW"].loc["2014-"+f"0{m}"])-1)
        stock2+=1000/data["Close"]["0050.TW"].loc["2014-"+f"0{m}"][n]
    else:
        n=random.randint(0,len(data["Close"]["0050.TW"].loc["2014-"+f"{m}"])-1)
        stock2+=1000/data["Close"]["0050.TW"].loc["2014-"+f"{m}"][n]
print(stock2)
print(stock2*data["Close"]["0050.TW"][-1])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\385159875.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# 235.162336440853
# 13019.447382021128
# 14035.549889869148
# 233.44759982730972
# 12924.513289036951
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\385159875.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   stock1+=1000/data["Close"]["0050.TW"].loc["2014-"+f"0{m}"][0]
# ...

# %%
import random
n=random.randint(1,len(data["0050.TW"].loc["2014-04"]))
print(n)
print(data["0050.TW"].loc["2014-04-01":"2014-04-30"])
print(data["0050.TW"].loc["2014-04-01":"2014-04-30"][n-1])
# Out:
# 21
# Date
# 2014-04-01    48.991680
# 2014-04-02    49.153374
# 2014-04-03    49.032108
# 2014-04-07    48.910843
# 2014-04-08    49.153374
# 2014-04-09    49.315063
# 2014-04-10    49.476749
# 2014-04-11    49.436329
# 2014-04-14    49.355488
# 2014-04-15    49.598019
# 2014-04-16    49.557590
# 2014-04-17    49.436329
# 2014-04-18    49.759708
# 2014-04-21    49.759708
# 2014-04-22    49.921394
# 2014-04-23    49.840557
# 2014-04-24    49.921394
# 2014-04-25    49.072529
# 2014-04-28    49.517170
# 2014-04-29    49.598019
# 2014-04-30    49.315063
# Name: 0050.TW, dtype: float64
# 49.3150634765625
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\156328196.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(data["0050.TW"].loc["2014-04-01":"2014-04-30"][n-1])

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import time
# 設定股票代號和數據的時間範圍
ID={}
stock_symbol = ['2330.TW',"0050.TW"]
start_year=2008
end_year=2015
for st in stock_symbol:
    ID[st]={}
for y in range(start_year,end_year):
    print(str(y)+'-01-01')
    start_date = str(y)+'-01-01'
    end_date = str(y)+'-12-31'

    # 使用yfinance來獲取股票數據
    data = yf.download(stock_symbol, start=start_date, end=end_date)["Close"]
    #計算ID值
    for stock in stock_symbol:
        data2=data[stock].pct_change()
        data2=data2.dropna()
        print(data2)
        up=0
        down=0
        for n in range(0,data2.size):
            if (data2[n]) > 0:
                up+=1
            elif (data2[n]) < 0:
                down+=1
        ID[stock][str(y)]=(down-up)/data2.size
        time.sleep(2)
ID
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\3440783915.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(stock_symbol, start=start_date, end=end_date)["Close"]
# [*********************100%***********************]  2 of 2 completed
# 2008-01-01
# Date
# 2008-01-03   -0.018182
# 2008-01-04    0.010101
# 2008-01-07   -0.070000
# 2008-01-08    0.003584
# 2008-01-09    0.017857
#                 ...
# 2008-12-24   -0.010263
# 2008-12-25   -0.006912
# 2008-12-26    0.006960
# 2008-12-29   -0.001152
# 2008-12-30    0.042676
# Name: 2330.TW, Length: 249, dtype: float64
# C:\Users\User\AppData\Local\Temp\ipykernel_4488\3440783915.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (data2[n]) > 0:
# ...

# %%
import pandas as pd
d1=pd.DataFrame({'2008':[] ,
  '2009': [],
  '2010': [],
  '2011': [],
  '2012': [],
  '2013': [],
  '2014':[]})
d1
# Out:
# Empty DataFrame
# Columns: [2008, 2009, 2010, 2011, 2012, 2013, 2014]
# Index: []

# %%
len(data['Close'])
# Out:
# 241

# %%
data2=data['Close'].pct_change()
data2.dropna()
r=[]
up=0
down=0
for n in range(0,data2.size):
    r.append(data2.iat[n,0])
    if (data2.iat[n,0]) > 0:
        up+=1
    elif (data2.iat[n,0]) < 0:
        down+=1
print((down-up)/data2.size)
# Out:
# -0.15352697095435686

# %%
# data=data["Close"].dropna()
r=[]
up=0
down=0
for n in range(0,data['Close'].size-1):
    r.append(data['Close'].iat[n+1,0]/data['Close'].iat[n,0]-1)
    if (data['Close'].iat[n+1,0]/data['Close'].iat[n,0]-1) > 0:
        up+=1
    elif (data['Close'].iat[n+1,0]/data['Close'].iat[n,0]-1) < 0:
        down+=1
print((down-up)/data['Close'].size)
# Out:
# -0.15352697095435686

# %%
import requests
re=requests.get("https://finance.yahoo.com/quote/1234.TW/")
re.text
# Out:
# 'Edge: Too Many Requests'
